# %% [markdown]
# <a href="https://colab.research.google.com/github/Anubhav-M5/ML-Self-EDA/blob/main/MACHINE_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('Advertising.csv')
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# EDA

# %%
#step 1:
# analyze tv
sns.distplot(data['TV'], kde=True)
# Out:
# <ipython-input-12-32445088dec6>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['TV'], kde=True)
# <Axes: xlabel='TV', ylabel='Density'>

# %%
#analyze newspaer
sns.distplot(data['Newspaper'], kde=True)
# Out:
# <ipython-input-13-c516b2446634>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Newspaper'], kde=True)
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
#analyze radio
sns.distplot(data['Radio'], kde=True)
sns.histplot(x=data.Radio, kde=True)
# Out:
# <ipython-input-18-48385cb7b86e>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Radio'], kde=True)
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
#analyze sales
sns.distplot(data['Sales'], kde=True)
# Out:
# <ipython-input-19-ace96b7005a5>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Sales'], kde=True)
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
#step 2 bivariate analysis
# this step is performed when inputs and outputs
#1st variable will be inputs
#2nd variable will be outputs

# %%
#analyze tv and sales
sns.relplot(x='TV', y='Sales', data=data)

# %%
#analyze radio and newspaer
sns.relplot(x='Radio', y='Sales', data=data)

# %%
#analyze radio and sales
sns.relplot(x='Newspaper', y='Sales', data=data)

# %%
sns.pairplot(data)

# %% [markdown]
# Data Preprocessing and feature engineering

# %%
#step 1. check missing values
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
#step 2 . checking the outlier
sns.boxplot(x = 'TV', data = data)
# Out:
# <Axes: xlabel='TV'>

# %%
sns.boxplot(x = 'Radio', data = data)
# Out:
# <Axes: xlabel='Radio'>

# %%
sns.boxplot(x = 'Newspaper', data = data)
# Out:
# <Axes: xlabel='Newspaper'>

# %% [markdown]
# Feature Selection

# %%
#step 1 Dropping the unwanted variables
l1 = ['Unnamed: 0']
data.drop(l1,axis=1,inplace = True)

# %%
#step 2.
sns.heatmap(data.drop('Sales',axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# MODEL CREATION

# %%
# step 1: independent and dependent variable creation
x = data[['TV','Radio','Newspaper']]
y = data.Sales

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
#step 2 Training and testing data creation
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train.shape
# Out:
# (160, 3)

# %%
x_test.shape
# Out:
# (40, 3)

# %%
y_train.shape
# Out:
# (160,)

# %%
y_test.shape
# Out:
# (40,)

# %%
#step 3 creating model

from sklearn.linear_model import LinearRegression
LR = LinearRegression() #object creation
LR
LR.fit(x_train,y_train) #model creation
# Out:
# LinearRegression()

# %%
y_predict = LR.predict(x_test)
y_predict
# Out:
# array([ 6.72296139, 13.75631244, 12.04517877,  9.69967488, 15.5690964 ,
#        10.05604087, 13.84462636, 11.57199727, 19.50132767, 10.63532913,
#        18.86878088,  7.66094904, 14.95238223, 16.44076381, 21.16915592,
#        20.34689481, 17.4717922 , 20.44501887,  6.6345129 , 11.59504468,
#        10.73339912, 14.9550131 , 20.47462735, 14.4053483 , 19.82336217,
#        21.23329569, 13.95616746, 23.25585899,  8.33169334, 20.72918361,
#        15.86252542, 15.18601062, 21.74577286, 18.34562985, 12.80653699,
#         9.38349318,  5.37438571, 12.02365628, 19.26275296,  8.12044348])

# %% [markdown]
# PREDICT WHEATHER THE PERSON HAVE DIBETICS OR NOT

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-6942cdb756ae> in <cell line: 0>()
#       1 import math
# ----> 2 print(mean_squared_error(y_test,y_predict))
#       3 print(math.sqrt(mean_squared_error(y_test,y_predict)))
#
# NameError: name 'mean_squared_error' is not defined
